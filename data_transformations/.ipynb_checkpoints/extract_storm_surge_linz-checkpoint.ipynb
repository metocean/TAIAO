# %% [markdown]
# ## Introduction
#
# #### This notebook shows how to extract the storm surge signal from LINZ tide gauge data at a specific station. Here we use Auckland (AUCT) sea level data previously downloaded (see `download_linz.ipynb` notebook).
#
# ## Install necessary python libraries
#
# #### First install some python libraries, if not already installed in your current python3 environment.

# %%
import sys
# !{sys.executable} -m pip install GitPython matplotlib wand fpdf
# Out:
# Collecting GitPython
#   Using cached GitPython-3.1.29-py3-none-any.whl (182 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 26.1 MB/s eta 0:00:00m eta 0:00:010:0101
# Collecting wand
#   Using cached Wand-0.6.10-py2.py3-none-any.whl (142 kB)
# Collecting fpdf
#   Using cached fpdf-1.7.2-py2.py3-none-any.whl
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from GitPython) (4.3.0)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting numpy>=1.17
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.8 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 27.0 MB/s eta 0:00:0031m30.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: wand, fpdf, smmap, pillow, numpy, kiwisolver, fonttools, cycler, matplotlib, gitdb, GitPython
# Successfully installed GitPython-3.1.29 cycler-0.11.0 fonttools-4.38.0 fpdf-1.7.2 gitdb-4.0.9 kiwisolver-1.4.4 matplotlib-3.5.3 numpy-1.21.6 pillow-9.3.0 smmap-5.0.0 wand-0.6.10

# %% [markdown]
# ### Clone/install github repositories
#
# #### Clone MetOcean storm_surge github repository to `/tmp` folder. This repository contain the python scripts necessary to perform all the LINZ sea level data analysis.

# %%
## TODO merge to main and remove branch from the clone command
from git import Repo

# Repo.clone_from('git@github.com:metocean/storm_surge.git', '/tmp/storm_surge')
Repo.clone_from('git@github.com:metocean/storm_surge.git', '/tmp/storm_surge', branch='linz_processing')

# %% [markdown]
# #### Clone and install Calypso Science Toto python library. From this library we will use the `LINZfile` class that reads the LINZ NetCDF and readme files into a pandas DataFrame object.

# %%
## TODO merge to main and remove branch from the clone command
# Repo.clone_from('git@github.com:calypso-science/Toto.git', ''/tmp/Toto')
Repo.clone_from('git@github.com:calypso-science/Toto.git', '/tmp/Toto', branch="storm_surge_project")
# !{sys.executable} -m pip install --no-cache-dir -r /tmp/Toto/requirements.txt
# !{sys.executable} -m pip install -e /tmp/Toto
# Out:
# Collecting git+https://github.com/python-windrose/windrose (from -r /tmp/Toto/requirements.txt (line 7))
#   Cloning https://github.com/python-windrose/windrose to /tmp/pip-req-build-t6pv3iz3
#   Running command git clone --filter=blob:none --quiet https://github.com/python-windrose/windrose /tmp/pip-req-build-t6pv3iz3
#   Resolved https://github.com/python-windrose/windrose to commit 7342238361b28943063b9b9669cb47bc81f568f2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/wesleybowman/UTide.git (from -r /tmp/Toto/requirements.txt (line 12))
#   Cloning https://github.com/wesleybowman/UTide.git to /tmp/pip-req-build-elxdzph6
#   Running command git clone --filter=blob:none --quiet https://github.com/wesleybowman/UTide.git /tmp/pip-req-build-elxdzph6
#   Resolved https://github.com/wesleybowman/UTide.git to commit b2bd8367e132dc896c4a96ff633aeefb45b0a87c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: matplotlib in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 2)) (3.5.3)
# Requirement already satisfied: pandas in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 3)) (1.3.5)
# Requirement already satisfied: future in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 4)) (0.18.2)
# Requirement already satisfied: scipy in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: xarray in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 6)) (0.20.2)
# Requirement already satisfied: openpyxl in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 8)) (3.0.10)
# Requirement already satisfied: pyyaml in /home/ccosta/.local/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 9)) (5.3.1)
# Requirement already satisfied: numba in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 10)) (0.56.4)
# Requirement already satisfied: numdifftools in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 11)) (0.9.41)
# Requirement already satisfied: six in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: netCDF4 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 14)) (1.6.1)
# Requirement already satisfied: grid_strategy in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 15)) (0.0.1)
# Requirement already satisfied: xlwt in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: xlrd in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: requests in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from -r /tmp/Toto/requirements.txt (line 18)) (2.28.1)
# Collecting pysqlite3
#   Downloading pysqlite3-0.4.7.tar.gz (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 124.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cycler>=0.10 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from matplotlib->-r /tmp/Toto/requirements.txt (line 2)) (9.3.0)
# Requirement already satisfied: pytz>=2017.3 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from pandas->-r /tmp/Toto/requirements.txt (line 3)) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from xarray->-r /tmp/Toto/requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: importlib-metadata in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from xarray->-r /tmp/Toto/requirements.txt (line 6)) (4.11.3)
# Requirement already satisfied: et-xmlfile in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from openpyxl->-r /tmp/Toto/requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: setuptools in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from numba->-r /tmp/Toto/requirements.txt (line 10)) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from numba->-r /tmp/Toto/requirements.txt (line 10)) (0.39.1)
# Requirement already satisfied: cftime in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from netCDF4->-r /tmp/Toto/requirements.txt (line 14)) (1.6.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from requests->-r /tmp/Toto/requirements.txt (line 18)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from requests->-r /tmp/Toto/requirements.txt (line 18)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from requests->-r /tmp/Toto/requirements.txt (line 18)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from requests->-r /tmp/Toto/requirements.txt (line 18)) (2022.9.24)
# Requirement already satisfied: zipp>=0.5 in /home/ccosta/miniconda3/envs/ipynbv2/lib/python3.7/site-packages (from importlib-metadata->xarray->-r /tmp/Toto/requirements.txt (line 6)) (3.8.0)
# Building wheels for collected packages: pysqlite3
#   Building wheel for pysqlite3 (setup.py) ... done
#   WARNING: Legacy build of wheel for 'pysqlite3' created no files.
#   Command arguments: /home/ccosta/miniconda3/envs/ipynbv2/bin/python -u -c '
#   exec(compile('"'"''"'"''"'"'
#   # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#   #
#   # - It imports setuptools before invoking setup.py, to enable projects that directly
#   #   import from `distutils.core` to work with newer packaging standards.
#   # - It provides a clear error message when setuptools is not installed.
#   # - It sets `sys.argv[0]` to the underlying `setup.py`, when invoking `setup.py` so
#   #   setuptools doesn'"'"'t think the script is `-c`. This avoids the following warning:
#   #     manifest_maker: standard file '"'"'-c'"'"' not found".
#   # - It generates a shim setup.py, for handling setup.cfg-only projects.
#   import os, sys, tokenize
#
#   try:
#       import setuptools
#   except ImportError as error:
#       print(
#           "ERROR: Can not execute `setup.py` since setuptools is not available in "
#           "the build environment.",
#           file=sys.stderr,
#       )
#       sys.exit(1)
#
#   __file__ = %r
#   sys.argv[0] = __file__
#
#   if os.path.exists(__file__):
#       filename = __file__
#       with tokenize.open(__file__) as f:
#           setup_py_code = f.read()
#   else:
#       filename = "<auto-generated setuptools caller>"
#       setup_py_code = "from setuptools import setup; setup()"
#
#   exec(compile(setup_py_code, filename, "exec"))
#   '"'"''"'"''"'"' % ('"'"'/tmp/pip-install-p_1il01a/pysqlite3_71066f06529448d58cc6b9880a7aa58f/setup.py'"'"',), "<pip-setuptools-caller>", "exec"))' bdist_wheel -d /tmp/pip-wheel-lzsf9f61
#   Command output: [use --verbose to show]
#   Running setup.py clean for pysqlite3
# Failed to build pysqlite3
# Installing collected packages: pysqlite3
#   Running setup.py install for pysqlite3 ... done
# Successfully installed pysqlite3
# Obtaining file:///tmp/Toto
#   Preparing metadata (setup.py) ... done
# Installing collected packages: toto
#   Running setup.py develop for toto
# Successfully installed toto-1.2.0

# %% [markdown]
# ### Read LINZ sea level data
# #### First we read LINZ sea level data previously downloaded.
# The `download_linz.ipynb` notebook illustrate how to get NetCDF and readme/information ascii file from the LINZ website. Here we will use data from Auckland LINZ station named "AUCT" as an example.
#
# The `read_linz` method takes two inputs, the full path of LINZ NetCDF file and the station vertical datum height. The second is optional and if provided, the code will use it to apply sensor vertical drifting corrections and    reference water level around zero. If omitted (default), no offset drifting correction will be applied and the sea level anomalies will be calculated in relation to the time average water level.
#
# In this example we use the New Zealand Vertical Datum 2016, equal to 3.1370 m at Auckland station (https://www.geodesy.linz.govt.nz/gdb/?code=DD1N). The datum heights for other LINZ stations can be found at https://www.linz.govt.nz/guidance/geodetic-system/coordinate-systems-used-new-zealand/vertical-datums/local-mean-sea-level-datums.

# %%
import sys
sys.path.append('/tmp/storm_surge/storm_surge/timeseries_processing/linz_waterlevel')
import LINZ

filein = '/tmp/linz/raw/AUCT/AUCT_raw.nc'
dfraw, lon, lat = LINZ.read_linz(filein, 3.1370)
# Out:
# Reading: /tmp/linz/raw/AUCT/AUCT_raw.nc
# Processing water levels for sensor 40
# Using datum height of 3.1370 m
# Reading offset drifting information from sensor 40
# Skipping Apr 2009 - Nov 2009: zero point drifting
# Correcting sensor offset drifting Dec 2009 - Apr 2011: 8.85
# Correcting sensor offset drifting May 2011 - May 2012: 8.68
# Skipping Jun 2012 - Aug 2012: zero point drifting
# Correcting sensor offset drifting Sep 2012 - Dec 2014: 8.41
# Correcting sensor offset drifting Jan 2015 - Aug 2017: 8.43
# Skipping Sep 2017 - Feb 2019: zero point drifting
# Correcting sensor offset drifting Mar 2019 - Dec 2019: 8.52
# Skipping Jan 2020 -> zero point drifting
# Processing water levels for sensor 41
# Using datum height of 3.1370 m
# Reading offset drifting information from sensor 41
# Correcting sensor offset drifting Apr 2009 - Feb 2011: 8.74
# Skipping Mar 2009 - Apr 2009:  zero point drifting
# Correcting sensor offset drifting May 2011 - May 2012: 8.70
# Skipping Jun 2012 - Aug 2012: sensor faulty
# Correcting sensor offset drifting Sep 2012 - Dec 2014: 8.53
# Skipping Jan 2015 -> zero point drifting, annual variation

# %% [markdown]
# #### Now we select which sensor we want to use.
#
# Each LINZ water level station has data from 2 sensors coded as `40` and `41`. The data processing will use data from 1 sensor only. Executing the following will plot a figure showing the data for both sensors (not shown here as we are using `%matplotlib qt` to be able to interact with the figure). Click on the sensor time series you want to use the data from. Here we choose sensor `40`.

# %%
# %matplotlib qt
from core_routines.check import plot_graph as select_sensor
import copy
import os
import matplotlib.pyplot as plt

tmpfolder = '/tmp'
df0 = copy.deepcopy(dfraw)

answer = select_sensor([dfraw, dfraw], \
                       ['elev40', 'elev41'], \
                       ['Click on this graph to choose sensor: 40','41'],
                       save=os.path.join(tmpfolder, 'raw_data.png'),
                       eventname='choose')

print('Waiting for button press')
plt.waitforbuttonpress()
print('Continuing')

## switch to right dataframe
if answer['axes'] == '41':
    sensor = '41'
    del df0['elev40']
else:
    sensor = '40'
    del df0['elev41']

print(f'Switching to sensor {sensor}')
df0.rename(columns={f'elev{sensor}':'elev'}, inplace=True)

del df0['time']
# Out:
# Waiting for button press
# Continuing
# Switching to sensor 40

# %% [markdown]
# The sea level data is loaded as `pandas DataFrame` shown bellow. We now switch to `%matplotlib inline` to visualize the sea level time series.

# %%
# %matplotlib inline

print(df0)
df0['elev'].plot();
# Out:
#                          elev  longitude  latitude
# time
# 2013-01-01 00:00:00  0.335001    174.783   -36.833
# 2013-01-01 00:01:00  0.323000    174.783   -36.833
# 2013-01-01 00:02:00  0.312000    174.783   -36.833
# 2013-01-01 00:03:00  0.303000    174.783   -36.833
# 2013-01-01 00:04:00  0.292000    174.783   -36.833
# ...                       ...        ...       ...
# 2018-01-01 23:55:00 -1.122000    174.783   -36.833
# 2018-01-01 23:56:00 -1.129000    174.783   -36.833
# 2018-01-01 23:57:00 -1.136000    174.783   -36.833
# 2018-01-01 23:58:00 -1.144000    174.783   -36.833
# 2018-01-01 23:59:00 -1.154000    174.783   -36.833
#
# [2596567 rows x 3 columns]

# %% [markdown]
# ### Data cleaning
# #### Automatic cleaning
# This step performs a number of automatic cleaning processes to the data. Here we enable a phase-space despiking as well as a threshold-based despiking and disable a piecewise fashion detrending (performed at each time segment separated by `NaNs`). These options can be changed as wanted. More information can be found at ...
# Before cleaning, a resample to hourly interval is performed, although this might not play a role in this example that the data is already hourly spaced.
# ##### TODO fill here path to clean_linz.py

# %%
from core_routines.toolbox import clean_linz

phasespace3d = True
despike = True
abs_threshold = 3
detrend_btw_gap = False

df1 = clean_linz(copy.deepcopy(df0),
                 dt=60,
                 phasespace3d=phasespace3d,
                 despike=despike,
                 abs_threshold=abs_threshold,
                 detrend_btw_gap=detrend_btw_gap)
# Out:
# 	Fill gap
# 	Resample to hourly
# 	Remove spike with phasespace3d
# 	Remove spike with abs threshold (if value exceeds)
# 	Finished automatic cleaning

# %% [markdown]
# This is how the sea level data looks like after the automatic cleaning. Note that the large negative spikes are now removed from the time series.

# %%
import datetime as dt

print(df1)
df1['elev'].plot();

plt.figure();
df1['elev'].plot();
plt.xlim(dt.datetime(2017, 7, 1), dt.datetime(2017, 7, 31))
# Out:
#                      longitude  latitude    filled  phasespace   despike  \
# time
# 2013-01-01 00:00:00    174.783   -36.833  0.335001    0.335001  0.335001
# 2013-01-01 01:00:00    174.783   -36.833 -0.254000   -0.254000 -0.254000
# 2013-01-01 02:00:00    174.783   -36.833 -0.842000   -0.842000 -0.842000
# 2013-01-01 03:00:00    174.783   -36.833 -1.249000   -1.249000 -1.249000
# 2013-01-01 04:00:00    174.783   -36.833 -1.335999   -1.335999 -1.335999
# ...                        ...       ...       ...         ...       ...
# 2018-01-01 19:00:00    174.783   -36.833  1.539000    1.539000  1.539000
# 2018-01-01 20:00:00    174.783   -36.833  1.402000    1.402000  1.402000
# 2018-01-01 21:00:00    174.783   -36.833  0.796000    0.796000  0.796000
# 2018-01-01 22:00:00    174.783   -36.833  0.118000    0.118000  0.118000
# 2018-01-01 23:00:00    174.783   -36.833 -0.565000   -0.565000 -0.565000
#
#                       detrend      elev
# time
# 2013-01-01 00:00:00  0.335001  0.335001
# 2013-01-01 01:00:00 -0.254000 -0.254000
# 2013-01-01 02:00:00 -0.842000 -0.842000
# 2013-01-01 03:00:00 -1.249000 -1.249000
# 2013-01-01 04:00:00 -1.335999 -1.335999
# ...                       ...       ...
# 2018-01-01 19:00:00  1.539000  1.539000
# 2018-01-01 20:00:00  1.402000  1.402000
# 2018-01-01 21:00:00  0.796000  0.796000
# 2018-01-01 22:00:00  0.118000  0.118000
# 2018-01-01 23:00:00 -0.565000 -0.565000
#
# [43848 rows x 7 columns]
# (416352.0, 417072.0)

# %% [markdown]
# #### Manual cleaning
# A manual cleaning can also be performed to delete some remaining unwanted data. Here we change back to `%matplotlib qt` to be able to interact with the figure. To delete unwanted data, simply click and hold the mouse left button and slide the mouse throught the x-axis until you cover the desired period. You'll be able to see a light grey background of the data that will be deleted. You can zoom in and out the time series by selecting the magnifying glass icon. When switching the pan or zoom icons on and off, the data that will be deleted is pointed with red markers. Once finished, simply close the figure. Here we delete some data at the beginning of July 2017.

# %%
# %matplotlib qt
from core_routines.check import plot_graph as clean_manually

answer = clean_manually([df0, df1], ['elev', 'elev'], ['Raw', 'Filter'], save=None, eventname='clean')

# %% [markdown]
# Now we add `NaN` to the unwanted data and save the time periods to be printed on the output log file later own.

# %%
from core_routines.toolbox import delete_manually
from matplotlib.dates import num2date

deleted_time = {}
if 'delete' in answer:
    df1['clean'] = delete_manually(df1['elev'], answer['delete'])

    for i, time in enumerate(answer['delete']):
        deleted_time[str(i+1)] = 'From %s to %s' % (num2date(time[0]).strftime('%Y-%m-%d %H:00'), num2date(time[1]).strftime('%Y-%m-%d %H:00'))

else:
    df1['clean'] = df1['elev']

df = df1['clean'].copy().to_frame()
df.rename(columns={'clean': 'elev'}, inplace=True)

# %% [markdown]
# This is how the final cleaned data looks like. Note that the sparse data around 6 July 2017 was deleted.

# %%
# %matplotlib inline

print(df)
df['elev'].plot();

plt.figure();
df1['elev'].plot();
plt.xlim(dt.datetime(2017, 7, 1), dt.datetime(2017, 7, 31))
# Out:
#                          elev
# time
# 2013-01-01 00:00:00  0.335001
# 2013-01-01 01:00:00 -0.254000
# 2013-01-01 02:00:00 -0.842000
# 2013-01-01 03:00:00 -1.249000
# 2013-01-01 04:00:00 -1.335999
# ...                       ...
# 2018-01-01 19:00:00  1.539000
# 2018-01-01 20:00:00  1.402000
# 2018-01-01 21:00:00  0.796000
# 2018-01-01 22:00:00  0.118000
# 2018-01-01 23:00:00 -0.565000
#
# [43848 rows x 1 columns]
# (416352.0, 417072.0)

# %% [markdown]
# ### Extract the storm surge signal

# %% [markdown]
# Now the data is clean and ready to be analysed. The following piece of code applies several filterings to the time series to split the sea level in different signals and get the storm surge component:
#
# - **trend**: sea level first order linear trend;
# - **tide**: astronomical tide computed from harmonic analysis of the main components (signal-to-noise ratio equal or larger than 2) using python Utide (https://github.com/wesleybowman/UTide);
# - **monthly mean sea level**: low frequency sea level variations of one month or larger periods obtained with a evenly weighted rolling window;
# - **storm surge**: atmospheric driven (winds and atmospheric pressure) sea level variations obtained with a low-pass cosine Lanczos squared filter (Walters and Heston, 1982, https://doi.org/10.1175/1520-0485(1982)012%3C0112:RTPVFT%3E2.0.CO;2);
# - **skew surge**: alternative definition for surge defined as the difference between the maximum observed total water level and the predicted high tide elevation over a tidal cycle (de Vries et al., 1995, https://doi.org/10.1016/0266-9838(95)00003-4);
#
# We are interested in the storm surge component. The `cutoff` variable is the Lanczos filter cutoff time (in hours) tuned to remove tides and inertial oscillations from the total water level and isolate the storm surge signal. Here we use 30 h, suitable for NZ latitudes.

# %%
from core_routines.toolbox import do_analysis

# filter cutoff time (in hours) to remove tides and inertial oscillations
cutoff = 30
folderout = '/tmp/linz/processed/AUCT/'
fileout = os.path.join(folderout, 'AUCT_processed.nc')

df = do_analysis(df['elev'], lat, cutoff=cutoff)
# Out:
# 	Storing NaNs position
# 	Detrending
# 	Tidal analysis
# {'trend': False, 'constit': 'auto', 'method': 'ols', 'conf_int': 'linear', 'Rayleigh_min': 2}
# solve: matrix prep ... solution ... done.
# prep/calcs ... done.
# 	Monthly mean filtering
# 	Storm surge filtering
# 	Skew surge filtering
# prep/calcs ... done.

# %% [markdown]
# The returned `DataFrame` has all the components the sea level was splitted into.

# %%
print(df)
# Out:
#                          elev  et     trend      tide      msea  ss  res  \
# time
# 2013-01-01 00:00:00  0.335001 NaN -0.160458  0.549297       NaN NaN  NaN
# 2013-01-01 01:00:00 -0.254000 NaN -0.160457 -0.032482  0.003355 NaN  NaN
# 2013-01-01 02:00:00 -0.842000 NaN -0.160456 -0.577988  0.003191 NaN  NaN
# 2013-01-01 03:00:00 -1.249000 NaN -0.160456 -0.980055  0.003014 NaN  NaN
# 2013-01-01 04:00:00 -1.335999 NaN -0.160455 -1.126600  0.002831 NaN  NaN
# ...                       ...  ..       ...       ...       ...  ..  ...
# 2018-01-01 19:00:00  1.539000 NaN -0.121071  1.497715  0.125766 NaN  NaN
# 2018-01-01 20:00:00  1.402000 NaN -0.121070  1.319591  0.125762 NaN  NaN
# 2018-01-01 21:00:00  0.796000 NaN -0.121069  0.769124  0.125753 NaN  NaN
# 2018-01-01 22:00:00  0.118000 NaN -0.121068  0.064518  0.125731 NaN  NaN
# 2018-01-01 23:00:00 -0.565000 NaN -0.121067 -0.600381  0.125771 NaN  NaN
#
#                      skew_surge_magnitude  skew_surge_lag  \
# time
# 2013-01-01 00:00:00                   NaN             NaN
# 2013-01-01 01:00:00                   NaN             NaN
# 2013-01-01 02:00:00                   NaN             NaN
# 2013-01-01 03:00:00                   NaN             NaN
# 2013-01-01 04:00:00                   NaN             NaN
# ...                                   ...             ...
# 2018-01-01 19:00:00                   NaN             NaN
# 2018-01-01 20:00:00                   NaN             NaN
# 2018-01-01 21:00:00                   NaN             NaN
# 2018-01-01 22:00:00                   NaN             NaN
# 2018-01-01 23:00:00                   NaN             NaN
#
#                      tidal_elevation_maximum_over_tidal_cycle  \
# time
# 2013-01-01 00:00:00                                       NaN
# 2013-01-01 01:00:00                                       NaN
# 2013-01-01 02:00:00                                       NaN
# 2013-01-01 03:00:00                                       NaN
# 2013-01-01 04:00:00                                       NaN
# ...                                                       ...
# 2018-01-01 19:00:00                                       NaN
# 2018-01-01 20:00:00                                       NaN
# 2018-01-01 21:00:00                                       NaN
# 2018-01-01 22:00:00                                       NaN
# 2018-01-01 23:00:00                                       NaN
#
#                     tidal_elevation_maximum_time_over_tidal_cycle  \
# time
# 2013-01-01 00:00:00                                           NaT
# 2013-01-01 01:00:00                                           NaT
# 2013-01-01 02:00:00                                           NaT
# 2013-01-01 03:00:00                                           NaT
# 2013-01-01 04:00:00                                           NaT
# ...                                                           ...
# 2018-01-01 19:00:00                                           NaT
# 2018-01-01 20:00:00                                           NaT
# 2018-01-01 21:00:00                                           NaT
# 2018-01-01 22:00:00                                           NaT
# 2018-01-01 23:00:00                                           NaT
#
#                      total_water_level_maximum_over_tidal_cycle
# time
# 2013-01-01 00:00:00                                         NaN
# 2013-01-01 01:00:00                                         NaN
# 2013-01-01 02:00:00                                         NaN
# 2013-01-01 03:00:00                                         NaN
# 2013-01-01 04:00:00                                         NaN
# ...                                                         ...
# 2018-01-01 19:00:00                                         NaN
# 2018-01-01 20:00:00                                         NaN
# 2018-01-01 21:00:00                                         NaN
# 2018-01-01 22:00:00                                         NaN
# 2018-01-01 23:00:00                                         NaN
#
# [43848 rows x 12 columns]

# %% [markdown]
# This is what the different sea level signals look like:

# %%
df['trend'].plot(title='sea level linear trend');

plt.figure();
df['tide'].plot(title='tidal sea level');

plt.figure();
df['msea'].plot(title='monthly mean sea level');

plt.figure();
df['ss'].plot(title='storm surge');

plt.figure();
df['skew_surge_magnitude'].dropna().plot(title='skew surge');

# %% [markdown]
# Zomming in the storm surge time series during 2014.

# %%
import datetime as dt

plt.figure();
df['ss'].plot(title='storm surge');
plt.xlim(dt.datetime(2014, 1, 1, 0, 0, 0), dt.datetime(2014, 12, 31, 23, 0, 0));

# %% [markdown]
# Now we zomm in at the storm surge peak occuring in mid March 2014 and plot the total water level and the tides together in the same figure. The total water level is already detrended and monthly mean removed. The positive difference between the observed (thin black line) total water level and the predicted tidal elevation (dashed blue line) is the storm surge (thick red line) caused by coastal sea level convergence favorable winds and low atmospheric pressure forcings (e.g. Pugh, 1987).

# %%
plt.figure();
df['et'].plot(linewidth=1, color='k', label='total water level');
df['tide'].plot(linestyle='--', label='tides');
df['ss'].plot(label='storm surge');
plt.legend(loc='best');
plt.xlim(dt.datetime(2014, 3, 12), dt.datetime(2014, 3, 18));
plt.ylim(-1.5, 1.5);

# %% [markdown]
# ## Save output files
#
# The following saves the analysed sea level data to a NetCDF file with a suffix "_processed" and a pdf file with all the steps taken to extract the storm surge signal.

# %%
# %matplotlib inline
from core_routines.toolbox import store_data_as_netcdf

folderout = '/tmp/linz/processed/AUCT/'
fileout = os.path.join(folderout, 'AUCT_processed.nc')

# save the analysed sea level into a NetCDF file
store_data_as_netcdf(df, lon, lat, fileout)

# save a pdf with the parameters used and the different steps taken
pdflog = os.path.join(folderout, 'AUCT_log.pdf')
prefix = 'AUCT'
LINZ.save_pdf(df, df1, pdflog, prefix, filein, fileout, cutoff, sensor, tmpfolder, \
         phasespace3d, despike, abs_threshold, detrend_btw_gap, \
         deleted_time, folderout)
# Out:
# Saving log to /tmp/linz/processed/AUCT/AUCT_log.pdf

# %% [markdown]
# The resulting pdf log is shown bellow:

# %%
from wand.image import Image

imageFromPdf = Image(filename='/tmp/linz/processed/AUCT/AUCT_log.pdf')
pages = len(imageFromPdf.sequence)  

image = Image(  
  width=imageFromPdf.width,  
  height=imageFromPdf.height * pages  
)  
for i in range(pages):  
  image.composite(  
  imageFromPdf.sequence[i],  
  top=imageFromPdf.height * i,  
  left=0  
)  
image.format="png"  
image
# Out:
# <wand.image.Image: acec678 'PNG' (595x12630)>
